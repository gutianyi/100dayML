# %%
import numpy as np
import matplotlib.pyplot as plt  
x1=[100,500,1000,2000,5000]
y1=[3.276449680328369, 16.667662858963013,32.14251494407654,64.64176058769226,161.2188642024994]
x2=[100,500,1000,2000,5000]
y2=[1.0603981018066406,4.8565309047698975, 9.8385169506073, 20.126548051834106, 49.4250328540802]
x3=[100,500,1000,2000,5000]
y3=[1.0563819408416748, 5.037948846817017, 9.691465854644775, 18.79610800743103, 47.69247794151306]

# %%
l1=plt.plot(x1,y1,'r--',label='BPNN')
l2=plt.plot(x2,y2,'g--',label='Taran')
l3=plt.plot(x3,y3,'b--',label='CrossTab')
# plt.plot(x1,y1,'ro-')
plt.plot(x1,y1,'ro-',x2,y2,'g+-',x3,y3,'b^-')
plt.title('The Time Tools Takes to Do Debug')
plt.xlabel('The Size of Datasets')
plt.ylabel('The time Spent(s)')
plt.legend()
plt.savefig('time.png')
plt.show()

# %%
x1=['1 bug','2 bugs','3 bugs','4bugs']
y1=[1/12,2/12,3/12,4/12]
x2=['1 bug','2 bugs','3 bugs','4bugs']
y2=[1/12,7/36,13/48,4/12]
x3=['1 bug','2 bugs','3 bugs','4bugs']
y3=[1/12,2/12,3/12,4/12]

l1=plt.plot(x1,y1,'r--',label='Taran')
l2=plt.plot(x2,y2,'g--',label='CrossTab')
l3=plt.plot(x3,y3,'b--',label='BPNN')
# plt.plot(x1,y1,'ro-')
plt.plot(x1,y1,'ro-',x2,y2,'g+-',x3,y3,'b^-')
plt.title('exam')
plt.xlabel('The number of bugs')
plt.ylabel('Exam Score)')
plt.ylim(0,0.5)
plt.legend()
plt.savefig('exam.png')
plt.show()
